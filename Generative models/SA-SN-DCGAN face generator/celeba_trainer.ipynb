# %% [markdown]
# The following cell defines all central functions needed for training the SA_SN_DCGAN, computing metrics, and displaying images.

# %%
#imports
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import keras
from keras import layers, activations
from keras.initializers import RandomNormal
from keras.applications import InceptionV3
from keras.applications.inception_v3 import preprocess_input
import matplotlib.pyplot as plt
import cv2
from skimage.transform import resize
from scipy.linalg import sqrtm
import numpy as np
import os, time
from skimage.metrics import structural_similarity, peak_signal_noise_ratio

#Inception (IS) score metric
def IS_score(image_list, n_split=10, epsilon=1E-16):
    model = InceptionV3()
    scores = []
    n_partition = image_list.shape[0]//n_split
    for idx in range(n_split):
        subset = image_list[idx*n_partition:(idx+1)*n_partition].astype('float32')
        subset = np.asarray([resize(image, (299,299,3), 0) for image in subset])
        subset = preprocess_input(subset)
        prediction_yx = model.predict(subset,verbose=0)
        prediction_y = np.expand_dims(prediction_yx.mean(axis=0), 0)
        KL_div = prediction_yx * (np.log(prediction_yx + epsilon) - np.log(prediction_y + epsilon))
        sum_KL_div = KL_div.sum(axis=1)
        avg_KL_div = np.mean(sum_KL_div)
        is_score = np.exp(avg_KL_div)
        scores.append(is_score)
    avg_IS,stdv_IS = np.mean(scores),np.std(scores)
    return avg_IS,stdv_IS

#FID score metric
def FID_score(images_1, images_2):
    model = InceptionV3(include_top=False, pooling='avg', input_shape=(299,299,3))
    images_1 = np.asarray([resize(image, (299,299,3), 0) for image in images_1])
    images_2 = np.asarray([resize(image, (299,299,3), 0) for image in images_2])
    activation_1,activation_2 = model.predict(images_1,verbose=0),model.predict(images_2,verbose=0)
    mu_1, sigma_1 = activation_1.mean(axis=0), np.cov(activation_1, rowvar=False)
    mu_2, sigma_2 = activation_2.mean(axis=0), np.cov(activation_2, rowvar=False)
    ss_difference = np.sum((mu_1-mu_2)**2.0)
    covariance_mean = sqrtm(sigma_1.dot(sigma_2))
    if np.iscomplexobj(covariance_mean):covariance_mean=covariance_mean.real
    fid_score = ss_difference + np.trace(sigma_1 + sigma_2 - 2.0*covariance_mean)
    return fid_score

#SSIM metric
def SSIM(images_1,images_2):
    total_SSIM = sum([structural_similarity(images_1[idx],images_2[idx],
                                            channel_axis=-1, data_range=255.0) for idx in range(len(images_1))])
    return total_SSIM/len(images_1)

#PSNR metric
def PSNR(images_1,images_2):
    total_PSNR = sum([peak_signal_noise_ratio(images_1[idx],images_2[idx]) for idx in range(len(images_1))])
    return total_PSNR/len(images_1)

#metrics helper function
def metrics(images_1,images_2):
    batch_size = len(images_2)

    total_avg_IS_score = 0
    total_std_IS_score = 0
    total_FID_score = 0
    total_SSIM_score = 0
    total_PSNR_score = 0

    #compute IS score averaged over batch size
    for idx in range(batch_size):
        avg,std = IS_score(images_1[idx])
        total_avg_IS_score+=avg
        total_std_IS_score+=std
    total_avg_IS_score/=batch_size
    total_std_IS_score/=batch_size

    #compute FID score averaged over batch size
    for idx in range(batch_size):
        total_FID_score+=FID_score(images_1[idx],images_2[idx])
    total_FID_score/=batch_size

    #compute SSIM score averaged over batch size
    for idx in range(batch_size):
        total_SSIM_score+=SSIM(images_1[idx],images_2[idx])
    total_SSIM_score/=batch_size

    #compute PSNR score averaged over batch size
    for idx in range(batch_size):
        total_PSNR_score+=PSNR(images_1[idx],images_2[idx])
    total_PSNR_score/=batch_size

    return total_avg_IS_score,total_std_IS_score,total_FID_score,total_SSIM_score,total_PSNR_score

#format generator output for display
def format_image(generator_output):
    unscaled_image = generator_output[0,:,:,:]
    scaled_image = (generator_output*127.5)+127.5
    clipped_image = np.clip(scaled_image,0.0,255.0)
    clipped_image/=255.0
    return clipped_image[0]

#display 9 images at once
def display_images():

    for idx in range(1,10):
        plt.subplot(3,3,idx)
        noise = tf.random.normal([1, 100])
        generated_image = generator(noise, training=False)
        img = format_image(generated_image)
        plt.imshow(img)
        plt.axis('off')
    plt.show()
    plt.clf()

#make generator following architecture outlined in paper
def make_generator_model():

    #input layer takes noise vector
    input_layer = keras.Input(shape=(100,))

    #fully connected layer without bias or activation to reshape input
    fcl = layers.Dense(4*4*3, use_bias=False,name='fcl')(input_layer)

    #reshape fully connected output
    reshape = layers.Reshape((4, 4, 3),name='reshape')(fcl)

    #transpose convolution block 1 using 512 filters, (mu=0,std=.02) normal initialization, batch normalization, and relu activation
    tconv1 = layers.Conv2DTranspose(512,3,padding='same',kernel_initializer=RandomNormal(mean=0.0, stddev=0.02),name='tconv1')(reshape)
    bnorm1 = layers.BatchNormalization()(tconv1)
    relu1 = layers.Activation(activations.relu)(bnorm1)

    #transpose convolution block 2 using 256 filters, (mu=0,std=.02) normal initialization, batch normalization, and relu activation
    tconv2 = layers.Conv2DTranspose(256,3,strides=2,padding='same',kernel_initializer=RandomNormal(mean=0.0, stddev=0.02),name='tconv2')(relu1)
    bnorm2 = layers.BatchNormalization()(tconv2)
    relu2 = layers.Activation(activations.relu)(bnorm2)

    #self attention layer
    attention = layers.MultiHeadAttention(1,256,kernel_initializer=RandomNormal(mean=0.0, stddev=0.02),name='attention')(relu2,relu2)

    #transpose convolution block 3 using 128 filters, (mu=0,std=.02) normal initialization, batch normalization, and relu activation
    tconv3 = layers.Conv2DTranspose(128,3,strides=2,padding='same',kernel_initializer=RandomNormal(mean=0.0, stddev=0.02),name='tconv3')(attention)
    bnorm3 = layers.BatchNormalization()(tconv3)
    relu3 = layers.Activation(activations.relu)(bnorm3)

    #transpose convolution block 4 using 64 filters, (mu=0,std=.02) normal initialization, batch normalization, and relu activation
    tconv4 = layers.Conv2DTranspose(64,3,strides=2,padding='same',kernel_initializer=RandomNormal(mean=0.0, stddev=0.02),name='tconv4')(tconv3)
    bnorm4 = layers.BatchNormalization()(tconv4)
    relu4 = layers.Activation(activations.relu)(bnorm4)

    #transpose convolution block 5 (output layer) using 3 filters, (mu=0,std=.02) normal initialization, batch normalization, and relu activation
    output_layer = layers.Conv2DTranspose(3,3,strides=2,padding='same',kernel_initializer=RandomNormal(mean=0.0, stddev=0.02),activation='tanh',name='output')(relu4)

    #assemble model
    model = keras.Model(inputs=input_layer, outputs=output_layer,name='generator')

    return model

#make discriminator following architecture outlined in paper
def make_discriminator_model():

    #input layer taking output from discriminator
    input_layer = keras.Input(shape=[64, 64, 3])

    #spectral normalization layer with 64 filters and leaky relu activation
    spec_norm = layers.SpectralNormalization(layers.Conv2D(64,3,strides=2,padding='same',name='spec_norm'))(input_layer)
    lrelu1 = layers.LeakyReLU(name='lrelu1')(spec_norm)

    #convolutional block 1 with 128 filters and leaky relu activation
    conv1 = layers.Conv2D(128,3,strides=2,padding='same',name='conv1')(lrelu1)
    bnorm1 = layers.BatchNormalization()(conv1)
    lrelu2 = layers.LeakyReLU(name='lrelu2')(bnorm1)

    #convolutional block 2 with 256 filters and leaky relu activation
    conv2 = layers.Conv2D(256,3,strides=2,padding='same',name='conv2')(lrelu2)
    bnorm2 = layers.BatchNormalization()(conv2)
    lrelu3 = layers.LeakyReLU(name='lrelu3')(conv2)

    #convolutional block 3 with 512 filters and leaky relu activation
    conv3 = layers.Conv2D(512,3,strides=2,padding='same',name='conv3')(lrelu3)
    bnorm3 = layers.BatchNormalization()(conv3)
    lrelu4 = layers.LeakyReLU(name='lrelu4')(conv3)

    #flatten convolutional block output
    flattened = layers.Flatten()(lrelu4)

    #spectral normalization output layer with (mu=0,std=.02) normal initialization, one unit and sigmoid activation (binary classification for real vs fake)
    output_layer = layers.SpectralNormalization(layers.Dense(1,kernel_initializer=RandomNormal(mean=0.0, stddev=0.02),activation='sigmoid',name='output_layer'))(flattened)

    #assemble model
    model = keras.Model(inputs=input_layer,outputs=output_layer,name='discriminator')

    return model

#discriminator loss takes real output (real images) and fake output (generator output)
#real output and fake output are the discriminators decisions on sets of real and fake images
def discriminator_loss(real_output, fake_output):

    #real loss is how far discriminator is from classifying real output from 1
    real_loss = cross_entropy(tf.ones_like(real_output), real_output)

    #fake loss is how far discriminator is from classifying fake output from 0
    fake_loss = cross_entropy(tf.zeros_like(fake_output), fake_output)

    #total discriminator loss is the sum of both losses
    total_loss = real_loss + fake_loss
    return total_loss

#generator loss takes fake output (the decisions from the descriminator on fake images)
def generator_loss(fake_output):
    #loss is how far the generator was from tricking the discriminator
    return cross_entropy(tf.ones_like(fake_output), fake_output)

#training function
@tf.function
def train_step(images):
    #generate batch of noise samples for the generator
    noise = tf.random.normal([BATCH_SIZE, noise_dim])

    with tf.GradientTape() as gen_tape, tf.GradientTape() as disc_tape:
        #get fake images from generator
        generated_images = generator(noise, training=True)
        #get classifications from discriminator on real images
        real_output = discriminator(images, training=True)
        #get classifications from discriminator on fake images
        fake_output = discriminator(generated_images, training=True)
        #get generator loss using discriminators decisions on its output
        g_loss = generator_loss(fake_output)
        d_loss = discriminator_loss(real_output, fake_output)
        #get discriminator loss based on how well it discerned real from fake
    #get gradients of the generator
    gradients_of_generator = gen_tape.gradient(g_loss, generator.trainable_variables)
    #get gradients of the discriminator
    gradients_of_discriminator = disc_tape.gradient(d_loss, discriminator.trainable_variables)

    #update generator weights
    generator_optimizer.apply_gradients(zip(gradients_of_generator, generator.trainable_variables))
    #update discriminator weights
    discriminator_optimizer.apply_gradients(zip(gradients_of_discriminator, discriminator.trainable_variables))

    return g_loss, d_loss

#training function
def train(dataset, epochs):
    losses = [[],[]]

    #for each epoch, apply train step and save generator and discriminator loss; time epoch
    for epoch in range(1,epochs+1):
        start_time = time.time()
        g_losses = []
        d_losses = []
        for image_batch in dataset:
            g_loss,d_loss = train_step(image_batch)
            g_losses.append(g_loss)
            d_losses.append(d_loss)
        losses[0].append(tf.math.reduce_mean(g_losses).numpy())
        losses[1].append(tf.math.reduce_mean(d_losses).numpy())
        epoch_time = round(time.time() - start_time)

        #display epoch information (time and losses)
        print("Epoch "+str(epoch)+": Generator loss: "+str(losses[0][-1])+"; Discriminator loss: "
              +str(losses[1][-1])+"; duration: "+str(epoch_time)+" seconds")

        #periodically display images following numbers in paper
        if (epoch==10 or epoch%50==0):
            print()
            display_images()
            print()

    return losses

#training and testing parameters
BATCH_SIZE = 64
IMG_SIZE = 64
TEST_BATCH_SIZE = 100
EPOCHS = 150
noise_dim = 100
test_size = 10000

# %% [markdown]
# The following cell defines the training loop and evaluation on celebA

# %%
#celebA dataset train directory
celebA_train_dir = "/content/drive/MyDrive/celebA/train"
#load celebA dataset training images
train_dataset = keras.utils.image_dataset_from_directory(
    celebA_train_dir, label_mode=None, image_size=(IMG_SIZE, IMG_SIZE), batch_size=BATCH_SIZE
)
#normalize images
train_dataset = train_dataset.map(lambda x: x / 255.0)

#celebA dataset test directory
celebA_test_dir = "/content/drive/MyDrive/celebA/test"
#load celebA dataset training images
test_dataset = keras.utils.image_dataset_from_directory(
    celebA_test_dir, label_mode=None, image_size=(IMG_SIZE, IMG_SIZE), batch_size=TEST_BATCH_SIZE
)
#normalize images
test_dataset = test_dataset.map(lambda x: x / 255.0)

print()

#cross entropy loss
cross_entropy = tf.keras.losses.BinaryCrossentropy(from_logits=True)

#define generator and discriminator optimizers
#Adam with learning rate .0002 as described in paper
generator_optimizer = tf.keras.optimizers.Adam(.0002)
discriminator_optimizer = tf.keras.optimizers.Adam(.0002)

#assemble generator
generator = make_generator_model()
#assemble discriminator
discriminator = make_discriminator_model()

#train combined DCGAN
history = train(train_dataset, EPOCHS)

#save generator weights; please change to appropriate path if retraining
generator.save_weights('/content/sample_data/celebA_generator.weights.h5')
#save discriminator weights; please change to appropriate path if retraining
discriminator.save_weights('/content/sample_data/celebA_discriminator.weights.h5')

#obtain ending losses
celebA_g_loss_final = history[0][-1]
celebA_d_loss_final = history[1][-1]

#print ending losses
print()
print("celebA dataset final losses:")
print("Generator: "+str(celebA_g_loss_final))
print("Discriminator: "+str(celebA_d_loss_final))
print()

#save training curves
celebA_training_curves = history

#plot training loss for generator and discriminator
epoch_indexes = [idx+1 for idx in range(EPOCHS)]
plt.plot(epoch_indexes,history[0],label='Generator Loss')
plt.plot(epoch_indexes,history[1],label='Discriminator Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title("celebA dataset\nGenerator vs discriminator loss")
plt.legend()
plt.show()
plt.clf()

test_generated_images = []

#generate test images using trained model
for i in range(TEST_BATCH_SIZE):
    test_noise = tf.random.normal([test_size//TEST_BATCH_SIZE, noise_dim])
    generated_images = generator(test_noise, training=False).numpy()
    formatted_images = []
    for img in generated_images:
        reshaped = np.reshape(img,(1,64,64,3))
        formatted_images.append(format_image(reshaped))
    test_generated_images.append(formatted_images)

test_generated_images = np.asarray(test_generated_images)
test_real_images = np.asarray([img.numpy() for img in test_dataset])
test_real_images = np.clip(test_real_images,0.0,255.0)

#obtain celebA metrics
celebA_metrics = metrics(test_generated_images,test_real_images)
celebA_avg_IS_score = float(celebA_metrics[0])
celebA_FID_score = celebA_metrics[2]
celebA_SSIM_score = celebA_metrics[3]
celebA_PSNR_score = celebA_metrics[4]

#print celebA metrics
print("celebA dataset metrics:")
print("IS score: "+str(celebA_avg_IS_score))
print("FID score: "+str(celebA_FID_score))
print("SSIM score: "+str(celebA_SSIM_score))
print("PSNR score: "+str(celebA_PSNR_score))
# Out:
# Found 30000 files.
# Found 10000 files.
# /usr/local/lib/python3.11/dist-packages/keras/src/backend/tensorflow/nn.py:780: UserWarning: "`binary_crossentropy` received `from_logits=True`, but the `output` argument was produced by a Sigmoid activation and thus does not represent logits. Was this intended?
#   output, from_logits = _get_logits(
# Epoch 1: Generator loss: 3.8487775; Discriminator loss: 0.18849547; duration: 640 seconds
# Epoch 2: Generator loss: 4.7383504; Discriminator loss: 0.14355084; duration: 34 seconds
# Epoch 3: Generator loss: 5.379884; Discriminator loss: 0.14391626; duration: 33 seconds
# Epoch 4: Generator loss: 5.810379; Discriminator loss: 0.11948859; duration: 34 seconds
# Epoch 5: Generator loss: 6.3751183; Discriminator loss: 0.100648075; duration: 34 seconds
# Epoch 6: Generator loss: 6.4903407; Discriminator loss: 0.08951965; duration: 34 seconds
# Epoch 7: Generator loss: 6.6502166; Discriminator loss: 0.080539234; duration: 34 seconds
# Epoch 8: Generator loss: 6.921413; Discriminator loss: 0.0722705; duration: 34 seconds
# Epoch 9: Generator loss: 8.263276; Discriminator loss: 0.04905229; duration: 33 seconds
# Epoch 10: Generator loss: 8.407326; Discriminator loss: 0.048257455; duration: 33 seconds
# Epoch 11: Generator loss: 9.064325; Discriminator loss: 0.052438036; duration: 34 seconds
# Epoch 12: Generator loss: 8.224541; Discriminator loss: 0.048036378; duration: 34 seconds
# Epoch 13: Generator loss: 8.658294; Discriminator loss: 0.03553835; duration: 34 seconds
# Epoch 14: Generator loss: 9.554226; Discriminator loss: 0.045264233; duration: 34 seconds
# Epoch 15: Generator loss: 9.351805; Discriminator loss: 0.032333605; duration: 33 seconds
# Epoch 16: Generator loss: 9.79574; Discriminator loss: 0.032617252; duration: 33 seconds
# Epoch 17: Generator loss: 10.273581; Discriminator loss: 0.02737134; duration: 33 seconds
# Epoch 18: Generator loss: 10.605743; Discriminator loss: 0.025447577; duration: 33 seconds
# Epoch 19: Generator loss: 9.976013; Discriminator loss: 0.03593238; duration: 34 seconds
# Epoch 20: Generator loss: 10.442811; Discriminator loss: 0.018343112; duration: 34 seconds
# Epoch 21: Generator loss: 14.264423; Discriminator loss: 0.018065503; duration: 34 seconds
# Epoch 22: Generator loss: 11.213913; Discriminator loss: 0.029398762; duration: 34 seconds
# Epoch 23: Generator loss: 10.896919; Discriminator loss: 0.029225547; duration: 33 seconds
# Epoch 24: Generator loss: 11.778807; Discriminator loss: 0.029170062; duration: 34 seconds
# Epoch 25: Generator loss: 10.512002; Discriminator loss: 0.030495964; duration: 34 seconds
# Epoch 26: Generator loss: 11.299093; Discriminator loss: 0.030754162; duration: 33 seconds
# Epoch 27: Generator loss: 11.402898; Discriminator loss: 0.024757711; duration: 33 seconds
# Epoch 28: Generator loss: 11.907789; Discriminator loss: 0.023924386; duration: 34 seconds
# Epoch 29: Generator loss: 11.919917; Discriminator loss: 0.028760463; duration: 33 seconds
# Epoch 30: Generator loss: 11.613021; Discriminator loss: 0.025311453; duration: 34 seconds
# Epoch 31: Generator loss: 12.551815; Discriminator loss: 0.024285052; duration: 34 seconds
# Epoch 32: Generator loss: 13.429673; Discriminator loss: 0.029359749; duration: 33 seconds
# Epoch 33: Generator loss: 11.732782; Discriminator loss: 0.022330657; duration: 34 seconds
# Epoch 34: Generator loss: 12.801766; Discriminator loss: 0.023932891; duration: 33 seconds
# Epoch 35: Generator loss: 11.945566; Discriminator loss: 0.023670956; duration: 33 seconds
# Epoch 36: Generator loss: 12.243523; Discriminator loss: 0.024131972; duration: 34 seconds
# Epoch 37: Generator loss: 11.405378; Discriminator loss: 0.025490684; duration: 33 seconds
# Epoch 38: Generator loss: 11.935857; Discriminator loss: 0.026537746; duration: 34 seconds
# Epoch 39: Generator loss: 11.503188; Discriminator loss: 0.023758708; duration: 34 seconds
# Epoch 40: Generator loss: 11.30714; Discriminator loss: 0.023530398; duration: 33 seconds
# Epoch 41: Generator loss: 12.017664; Discriminator loss: 0.02394464; duration: 34 seconds
# Epoch 42: Generator loss: 11.991993; Discriminator loss: 0.023833549; duration: 33 seconds
# Epoch 43: Generator loss: 13.277538; Discriminator loss: 0.02166359; duration: 33 seconds
# Epoch 44: Generator loss: 13.908416; Discriminator loss: 0.01843562; duration: 33 seconds
# Epoch 45: Generator loss: 13.292847; Discriminator loss: 0.0236411; duration: 33 seconds
# Epoch 46: Generator loss: 12.075022; Discriminator loss: 0.024598388; duration: 34 seconds
# Epoch 47: Generator loss: 13.235443; Discriminator loss: 0.02083468; duration: 33 seconds
# Epoch 48: Generator loss: 13.365752; Discriminator loss: 0.019961944; duration: 33 seconds
# Epoch 49: Generator loss: 13.201685; Discriminator loss: 0.019247178; duration: 34 seconds
# Epoch 50: Generator loss: 14.14537; Discriminator loss: 0.021913314; duration: 34 seconds
# Epoch 51: Generator loss: 13.602351; Discriminator loss: 0.025957428; duration: 33 seconds
# Epoch 52: Generator loss: 13.689851; Discriminator loss: 0.020821106; duration: 34 seconds
# Epoch 53: Generator loss: 14.023617; Discriminator loss: 0.025654728; duration: 33 seconds
# Epoch 54: Generator loss: 14.081444; Discriminator loss: 0.022425158; duration: 34 seconds
# Epoch 55: Generator loss: 13.739152; Discriminator loss: 0.029107492; duration: 34 seconds
# Epoch 56: Generator loss: 12.473913; Discriminator loss: 0.026744954; duration: 33 seconds
# Epoch 57: Generator loss: 12.721206; Discriminator loss: 0.02442983; duration: 34 seconds
# Epoch 58: Generator loss: 12.543123; Discriminator loss: 0.023283798; duration: 34 seconds
# Epoch 59: Generator loss: 11.936139; Discriminator loss: 0.02167191; duration: 34 seconds
# Epoch 60: Generator loss: 13.67206; Discriminator loss: 0.027883211; duration: 34 seconds
# Epoch 61: Generator loss: 13.545433; Discriminator loss: 0.023059957; duration: 33 seconds
# Epoch 62: Generator loss: 13.780493; Discriminator loss: 0.027723284; duration: 34 seconds
# Epoch 63: Generator loss: 12.349461; Discriminator loss: 0.023183838; duration: 34 seconds
# Epoch 64: Generator loss: 14.8358965; Discriminator loss: 0.028951008; duration: 34 seconds
# Epoch 65: Generator loss: 12.692153; Discriminator loss: 0.016522922; duration: 34 seconds
# Epoch 66: Generator loss: 15.257577; Discriminator loss: 0.026410477; duration: 34 seconds
# Epoch 67: Generator loss: 16.36765; Discriminator loss: 0.027081447; duration: 34 seconds
# Epoch 68: Generator loss: 14.988262; Discriminator loss: 0.030838106; duration: 34 seconds
# Epoch 69: Generator loss: 12.485465; Discriminator loss: 0.02583265; duration: 34 seconds
# Epoch 70: Generator loss: 13.083221; Discriminator loss: 0.020399345; duration: 33 seconds
# Epoch 71: Generator loss: 13.031922; Discriminator loss: 0.021854486; duration: 34 seconds
# Epoch 72: Generator loss: 13.920485; Discriminator loss: 0.024457201; duration: 34 seconds
# Epoch 73: Generator loss: 12.563731; Discriminator loss: 0.024102798; duration: 33 seconds
# Epoch 74: Generator loss: 13.203464; Discriminator loss: 0.021028357; duration: 34 seconds
# Epoch 75: Generator loss: 13.740794; Discriminator loss: 0.02647663; duration: 34 seconds
# Epoch 76: Generator loss: 13.494486; Discriminator loss: 0.029474262; duration: 34 seconds
# Epoch 77: Generator loss: 12.85214; Discriminator loss: 0.020113172; duration: 33 seconds
# Epoch 78: Generator loss: 13.147677; Discriminator loss: 0.022469958; duration: 33 seconds
# Epoch 79: Generator loss: 13.1327715; Discriminator loss: 0.03044756; duration: 33 seconds
# Epoch 80: Generator loss: 13.394584; Discriminator loss: 0.030184185; duration: 34 seconds
# Epoch 81: Generator loss: 12.783088; Discriminator loss: 0.029059626; duration: 34 seconds
# Epoch 82: Generator loss: 12.868903; Discriminator loss: 0.029641123; duration: 34 seconds
# Epoch 83: Generator loss: 12.207987; Discriminator loss: 0.02332019; duration: 34 seconds
# Epoch 84: Generator loss: 12.465912; Discriminator loss: 0.035457104; duration: 33 seconds
# Epoch 85: Generator loss: 13.268143; Discriminator loss: 0.029668063; duration: 33 seconds
# Epoch 86: Generator loss: 15.669455; Discriminator loss: 0.029281259; duration: 34 seconds
# Epoch 87: Generator loss: 12.372641; Discriminator loss: 0.025178105; duration: 34 seconds
# Epoch 88: Generator loss: 12.228325; Discriminator loss: 0.020553155; duration: 34 seconds
# Epoch 89: Generator loss: 12.451614; Discriminator loss: 0.025489388; duration: 34 seconds
# Epoch 90: Generator loss: 11.797841; Discriminator loss: 0.02165417; duration: 34 seconds
# Epoch 91: Generator loss: 11.736131; Discriminator loss: 0.020616468; duration: 34 seconds
# Epoch 92: Generator loss: 12.609899; Discriminator loss: 0.028772555; duration: 34 seconds
# Epoch 93: Generator loss: 12.419233; Discriminator loss: 0.04098082; duration: 34 seconds
# Epoch 94: Generator loss: 11.121136; Discriminator loss: 0.03066284; duration: 34 seconds
# Epoch 95: Generator loss: 11.11636; Discriminator loss: 0.027406616; duration: 34 seconds
# Epoch 96: Generator loss: 12.1465845; Discriminator loss: 0.033317823; duration: 34 seconds
# Epoch 97: Generator loss: 11.914949; Discriminator loss: 0.03147321; duration: 33 seconds
# Epoch 98: Generator loss: 12.662731; Discriminator loss: 0.03260769; duration: 34 seconds
# Epoch 99: Generator loss: 12.886126; Discriminator loss: 0.03265689; duration: 34 seconds
# Epoch 100: Generator loss: 12.872524; Discriminator loss: 0.03545048; duration: 34 seconds
# Epoch 101: Generator loss: 12.800727; Discriminator loss: 0.038214806; duration: 33 seconds
# Epoch 102: Generator loss: 11.743452; Discriminator loss: 0.02097067; duration: 34 seconds
# Epoch 103: Generator loss: 14.828364; Discriminator loss: 0.030984784; duration: 34 seconds
# Epoch 104: Generator loss: 12.80909; Discriminator loss: 0.032005683; duration: 34 seconds
# Epoch 105: Generator loss: 11.713587; Discriminator loss: 0.016935134; duration: 34 seconds
# Epoch 106: Generator loss: 12.034186; Discriminator loss: 0.028353844; duration: 34 seconds
# Epoch 107: Generator loss: 10.984705; Discriminator loss: 0.02233993; duration: 34 seconds
# Epoch 108: Generator loss: 13.140407; Discriminator loss: 0.02523855; duration: 33 seconds
# Epoch 109: Generator loss: 12.81559; Discriminator loss: 0.028876275; duration: 34 seconds
# Epoch 110: Generator loss: 13.324893; Discriminator loss: 0.025785929; duration: 33 seconds
# Epoch 111: Generator loss: 12.486138; Discriminator loss: 0.024936583; duration: 33 seconds
# Epoch 112: Generator loss: 12.1163; Discriminator loss: 0.02937135; duration: 34 seconds
# Epoch 113: Generator loss: 13.054996; Discriminator loss: 0.02900395; duration: 34 seconds
# Epoch 114: Generator loss: 14.082805; Discriminator loss: 0.032672025; duration: 33 seconds
# Epoch 115: Generator loss: 13.065733; Discriminator loss: 0.03199966; duration: 34 seconds
# Epoch 116: Generator loss: 12.272312; Discriminator loss: 0.022215405; duration: 34 seconds
# Epoch 117: Generator loss: 14.470386; Discriminator loss: 0.02395951; duration: 34 seconds
# Epoch 118: Generator loss: 13.725031; Discriminator loss: 0.030376311; duration: 33 seconds
# Epoch 119: Generator loss: 12.819439; Discriminator loss: 0.028412262; duration: 34 seconds
# Epoch 120: Generator loss: 13.8152275; Discriminator loss: 0.0323064; duration: 33 seconds
# Epoch 121: Generator loss: 13.410482; Discriminator loss: 0.030285163; duration: 34 seconds
# Epoch 122: Generator loss: 13.228407; Discriminator loss: 0.02807352; duration: 33 seconds
# Epoch 123: Generator loss: 12.612154; Discriminator loss: 0.028336776; duration: 34 seconds
# Epoch 124: Generator loss: 12.325973; Discriminator loss: 0.027531242; duration: 34 seconds
# Epoch 125: Generator loss: 12.81099; Discriminator loss: 0.028979894; duration: 33 seconds
# Epoch 126: Generator loss: 12.995428; Discriminator loss: 0.027966065; duration: 34 seconds
# Epoch 127: Generator loss: 11.152885; Discriminator loss: 0.02009701; duration: 33 seconds
# Epoch 128: Generator loss: 14.189066; Discriminator loss: 0.03410956; duration: 33 seconds
# Epoch 129: Generator loss: 12.719502; Discriminator loss: 0.03019104; duration: 34 seconds
# Epoch 130: Generator loss: 13.209259; Discriminator loss: 0.04249588; duration: 33 seconds
# Epoch 131: Generator loss: 11.628638; Discriminator loss: 0.022156363; duration: 34 seconds
# Epoch 132: Generator loss: 12.0435295; Discriminator loss: 0.025644993; duration: 34 seconds
# Epoch 133: Generator loss: 12.984252; Discriminator loss: 0.027903136; duration: 34 seconds
# Epoch 134: Generator loss: 12.423166; Discriminator loss: 0.022648457; duration: 34 seconds
# Epoch 135: Generator loss: 13.026721; Discriminator loss: 0.02503495; duration: 34 seconds
# Epoch 136: Generator loss: 13.920644; Discriminator loss: 0.030008968; duration: 34 seconds
# Epoch 137: Generator loss: 13.607607; Discriminator loss: 0.02894778; duration: 33 seconds
# Epoch 138: Generator loss: 12.649023; Discriminator loss: 0.022124887; duration: 34 seconds
# Epoch 139: Generator loss: 14.072343; Discriminator loss: 0.028876597; duration: 33 seconds
# Epoch 140: Generator loss: 13.681336; Discriminator loss: 0.02526292; duration: 33 seconds
# Epoch 141: Generator loss: 13.412826; Discriminator loss: 0.022434426; duration: 34 seconds
# Epoch 142: Generator loss: 13.084009; Discriminator loss: 0.028445583; duration: 34 seconds
# Epoch 143: Generator loss: 14.364225; Discriminator loss: 0.034983214; duration: 34 seconds
# Epoch 144: Generator loss: 13.552812; Discriminator loss: 0.030389147; duration: 34 seconds
# Epoch 145: Generator loss: 13.051409; Discriminator loss: 0.022189267; duration: 35 seconds
# Epoch 146: Generator loss: 12.203412; Discriminator loss: 0.026219629; duration: 34 seconds
# Epoch 147: Generator loss: 13.423296; Discriminator loss: 0.029979892; duration: 34 seconds
# Epoch 148: Generator loss: 13.481557; Discriminator loss: 0.029076006; duration: 34 seconds
# Epoch 149: Generator loss: 13.300483; Discriminator loss: 0.026914122; duration: 33 seconds
# Epoch 150: Generator loss: 12.942787; Discriminator loss: 0.026733968; duration: 34 seconds
# celebA dataset final losses:
# Generator: 12.942787
# Discriminator: 0.026733968
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_v3/inception_v3_weights_tf_dim_ordering_tf_kernels.h5
# 96112376/96112376 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_v3/inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5
# 87910968/87910968 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# celebA dataset metrics:
# IS score: 1.000460147857666
# FID score: 234.10558593960377
# SSIM score: 0.97799355
# PSNR score: 8.009645296063267
