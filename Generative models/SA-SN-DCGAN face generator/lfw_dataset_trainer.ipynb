# %% [markdown]
# The following cell defines all central functions needed for training the SA_SN_DCGAN, computing metrics, and displaying images.

# %%
#imports
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import keras
from keras import layers, activations
from keras.initializers import RandomNormal
from keras.applications import InceptionV3
from keras.applications.inception_v3 import preprocess_input
import matplotlib.pyplot as plt
import cv2
from skimage.transform import resize
from scipy.linalg import sqrtm
import numpy as np
import os, time
from skimage.metrics import structural_similarity, peak_signal_noise_ratio

#Inception (IS) score metric
def IS_score(image_list, n_split=10, epsilon=1E-16):
    model = InceptionV3()
    scores = []
    n_partition = image_list.shape[0]//n_split
    for idx in range(n_split):
        subset = image_list[idx*n_partition:(idx+1)*n_partition].astype('float32')
        subset = np.asarray([resize(image, (299,299,3), 0) for image in subset])
        subset = preprocess_input(subset)
        prediction_yx = model.predict(subset,verbose=0)
        prediction_y = np.expand_dims(prediction_yx.mean(axis=0), 0)
        KL_div = prediction_yx * (np.log(prediction_yx + epsilon) - np.log(prediction_y + epsilon))
        sum_KL_div = KL_div.sum(axis=1)
        avg_KL_div = np.mean(sum_KL_div)
        is_score = np.exp(avg_KL_div)
        scores.append(is_score)
    avg_IS,stdv_IS = np.mean(scores),np.std(scores)
    return avg_IS,stdv_IS

#FID score metric
def FID_score(images_1, images_2):
    model = InceptionV3(include_top=False, pooling='avg', input_shape=(299,299,3))
    images_1 = np.asarray([resize(image, (299,299,3), 0) for image in images_1])
    images_2 = np.asarray([resize(image, (299,299,3), 0) for image in images_2])
    activation_1,activation_2 = model.predict(images_1,verbose=0),model.predict(images_2,verbose=0)
    mu_1, sigma_1 = activation_1.mean(axis=0), np.cov(activation_1, rowvar=False)
    mu_2, sigma_2 = activation_2.mean(axis=0), np.cov(activation_2, rowvar=False)
    ss_difference = np.sum((mu_1-mu_2)**2.0)
    covariance_mean = sqrtm(sigma_1.dot(sigma_2))
    if np.iscomplexobj(covariance_mean):covariance_mean=covariance_mean.real
    fid_score = ss_difference + np.trace(sigma_1 + sigma_2 - 2.0*covariance_mean)
    return fid_score

#SSIM metric
def SSIM(images_1,images_2):
    total_SSIM = sum([structural_similarity(images_1[idx],images_2[idx],
                                            channel_axis=-1, data_range=255.0) for idx in range(len(images_1))])
    return total_SSIM/len(images_1)

#PSNR metric
def PSNR(images_1,images_2):
    total_PSNR = sum([peak_signal_noise_ratio(images_1[idx],images_2[idx]) for idx in range(len(images_1))])
    return total_PSNR/len(images_1)

#metrics helper function
def metrics(images_1,images_2):
    batch_size = len(images_2)

    total_avg_IS_score = 0
    total_std_IS_score = 0
    total_FID_score = 0
    total_SSIM_score = 0
    total_PSNR_score = 0

    #compute IS score averaged over batch size
    for idx in range(batch_size):
        avg,std = IS_score(images_1[idx])
        total_avg_IS_score+=avg
        total_std_IS_score+=std
    total_avg_IS_score/=batch_size
    total_std_IS_score/=batch_size

    #compute FID score averaged over batch size
    for idx in range(batch_size):
        total_FID_score+=FID_score(images_1[idx],images_2[idx])
    total_FID_score/=batch_size

    #compute SSIM score averaged over batch size
    for idx in range(batch_size):
        total_SSIM_score+=SSIM(images_1[idx],images_2[idx])
    total_SSIM_score/=batch_size

    #compute PSNR score averaged over batch size
    for idx in range(batch_size):
        total_PSNR_score+=PSNR(images_1[idx],images_2[idx])
    total_PSNR_score/=batch_size

    return total_avg_IS_score,total_std_IS_score,total_FID_score,total_SSIM_score,total_PSNR_score

#format generator output for display
def format_image(generator_output):
    unscaled_image = generator_output[0,:,:,:]
    scaled_image = (generator_output*127.5)+127.5
    clipped_image = np.clip(scaled_image,0.0,255.0)
    clipped_image/=255.0
    return clipped_image[0]

#display 9 images at once
def display_images():

    for idx in range(1,10):
        plt.subplot(3,3,idx)
        noise = tf.random.normal([1, 100])
        generated_image = generator(noise, training=False)
        img = format_image(generated_image)
        plt.imshow(img)
        plt.axis('off')
    plt.show()
    plt.clf()

#make generator following architecture outlined in paper
def make_generator_model():

    #input layer takes noise vector
    input_layer = keras.Input(shape=(100,))

    #fully connected layer without bias or activation to reshape input
    fcl = layers.Dense(4*4*3, use_bias=False,name='fcl')(input_layer)

    #reshape fully connected output
    reshape = layers.Reshape((4, 4, 3),name='reshape')(fcl)

    #transpose convolution block 1 using 512 filters, (mu=0,std=.02) normal initialization, batch normalization, and relu activation
    tconv1 = layers.Conv2DTranspose(512,3,padding='same',kernel_initializer=RandomNormal(mean=0.0, stddev=0.02),name='tconv1')(reshape)
    bnorm1 = layers.BatchNormalization()(tconv1)
    relu1 = layers.Activation(activations.relu)(bnorm1)

    #transpose convolution block 2 using 256 filters, (mu=0,std=.02) normal initialization, batch normalization, and relu activation
    tconv2 = layers.Conv2DTranspose(256,3,strides=2,padding='same',kernel_initializer=RandomNormal(mean=0.0, stddev=0.02),name='tconv2')(relu1)
    bnorm2 = layers.BatchNormalization()(tconv2)
    relu2 = layers.Activation(activations.relu)(bnorm2)

    #self attention layer
    attention = layers.MultiHeadAttention(1,256,kernel_initializer=RandomNormal(mean=0.0, stddev=0.02),name='attention')(relu2,relu2)

    #transpose convolution block 3 using 128 filters, (mu=0,std=.02) normal initialization, batch normalization, and relu activation
    tconv3 = layers.Conv2DTranspose(128,3,strides=2,padding='same',kernel_initializer=RandomNormal(mean=0.0, stddev=0.02),name='tconv3')(attention)
    bnorm3 = layers.BatchNormalization()(tconv3)
    relu3 = layers.Activation(activations.relu)(bnorm3)

    #transpose convolution block 4 using 64 filters, (mu=0,std=.02) normal initialization, batch normalization, and relu activation
    tconv4 = layers.Conv2DTranspose(64,3,strides=2,padding='same',kernel_initializer=RandomNormal(mean=0.0, stddev=0.02),name='tconv4')(tconv3)
    bnorm4 = layers.BatchNormalization()(tconv4)
    relu4 = layers.Activation(activations.relu)(bnorm4)

    #transpose convolution block 5 (output layer) using 3 filters, (mu=0,std=.02) normal initialization, batch normalization, and relu activation
    output_layer = layers.Conv2DTranspose(3,3,strides=2,padding='same',kernel_initializer=RandomNormal(mean=0.0, stddev=0.02),activation='tanh',name='output')(relu4)

    #assemble model
    model = keras.Model(inputs=input_layer, outputs=output_layer,name='generator')

    return model

#make discriminator following architecture outlined in paper
def make_discriminator_model():

    #input layer taking output from discriminator
    input_layer = keras.Input(shape=[64, 64, 3])

    #spectral normalization layer with 64 filters and leaky relu activation
    spec_norm = layers.SpectralNormalization(layers.Conv2D(64,3,strides=2,padding='same',name='spec_norm'))(input_layer)
    lrelu1 = layers.LeakyReLU(name='lrelu1')(spec_norm)

    #convolutional block 1 with 128 filters and leaky relu activation
    conv1 = layers.Conv2D(128,3,strides=2,padding='same',name='conv1')(lrelu1)
    bnorm1 = layers.BatchNormalization()(conv1)
    lrelu2 = layers.LeakyReLU(name='lrelu2')(bnorm1)

    #convolutional block 2 with 256 filters and leaky relu activation
    conv2 = layers.Conv2D(256,3,strides=2,padding='same',name='conv2')(lrelu2)
    bnorm2 = layers.BatchNormalization()(conv2)
    lrelu3 = layers.LeakyReLU(name='lrelu3')(conv2)

    #convolutional block 3 with 512 filters and leaky relu activation
    conv3 = layers.Conv2D(512,3,strides=2,padding='same',name='conv3')(lrelu3)
    bnorm3 = layers.BatchNormalization()(conv3)
    lrelu4 = layers.LeakyReLU(name='lrelu4')(conv3)

    #flatten convolutional block output
    flattened = layers.Flatten()(lrelu4)

    #spectral normalization output layer with (mu=0,std=.02) normal initialization, one unit and sigmoid activation (binary classification for real vs fake)
    output_layer = layers.SpectralNormalization(layers.Dense(1,kernel_initializer=RandomNormal(mean=0.0, stddev=0.02),activation='sigmoid',name='output_layer'))(flattened)

    #assemble model
    model = keras.Model(inputs=input_layer,outputs=output_layer,name='discriminator')

    return model

#discriminator loss takes real output (real images) and fake output (generator output)
#real output and fake output are the discriminators decisions on sets of real and fake images
def discriminator_loss(real_output, fake_output):

    #real loss is how far discriminator is from classifying real output from 1
    real_loss = cross_entropy(tf.ones_like(real_output), real_output)

    #fake loss is how far discriminator is from classifying fake output from 0
    fake_loss = cross_entropy(tf.zeros_like(fake_output), fake_output)

    #total discriminator loss is the sum of both losses
    total_loss = real_loss + fake_loss
    return total_loss

#generator loss takes fake output (the decisions from the descriminator on fake images)
def generator_loss(fake_output):
    #loss is how far the generator was from tricking the discriminator
    return cross_entropy(tf.ones_like(fake_output), fake_output)

#training function
@tf.function
def train_step(images):
    #generate batch of noise samples for the generator
    noise = tf.random.normal([BATCH_SIZE, noise_dim])

    with tf.GradientTape() as gen_tape, tf.GradientTape() as disc_tape:
        #get fake images from generator
        generated_images = generator(noise, training=True)
        #get classifications from discriminator on real images
        real_output = discriminator(images, training=True)
        #get classifications from discriminator on fake images
        fake_output = discriminator(generated_images, training=True)
        #get generator loss using discriminators decisions on its output
        g_loss = generator_loss(fake_output)
        d_loss = discriminator_loss(real_output, fake_output)
        #get discriminator loss based on how well it discerned real from fake
    #get gradients of the generator
    gradients_of_generator = gen_tape.gradient(g_loss, generator.trainable_variables)
    #get gradients of the discriminator
    gradients_of_discriminator = disc_tape.gradient(d_loss, discriminator.trainable_variables)

    #update generator weights
    generator_optimizer.apply_gradients(zip(gradients_of_generator, generator.trainable_variables))
    #update discriminator weights
    discriminator_optimizer.apply_gradients(zip(gradients_of_discriminator, discriminator.trainable_variables))

    return g_loss, d_loss

#training function
def train(dataset, epochs):
    losses = [[],[]]

    #for each epoch, apply train step and save generator and discriminator loss; time epoch
    for epoch in range(1,epochs+1):
        start_time = time.time()
        g_losses = []
        d_losses = []
        for image_batch in dataset:
            g_loss,d_loss = train_step(image_batch)
            g_losses.append(g_loss)
            d_losses.append(d_loss)
        losses[0].append(tf.math.reduce_mean(g_losses).numpy())
        losses[1].append(tf.math.reduce_mean(d_losses).numpy())
        epoch_time = round(time.time() - start_time)

        #display epoch information (time and losses)
        print("Epoch "+str(epoch)+": Generator loss: "+str(losses[0][-1])+"; Discriminator loss: "
              +str(losses[1][-1])+"; duration: "+str(epoch_time)+" seconds")

        #periodically display images following numbers in paper
        if (epoch==10 or epoch%50==0):
            print()
            display_images()
            print()

    return losses

#training and testing parameters
BATCH_SIZE = 64
IMG_SIZE = 64
TEST_BATCH_SIZE = 100
EPOCHS = 150
noise_dim = 100
test_size = 3000

# %% [markdown]
# The following cell defines the training loop and evaluation on LFW dataset

# %%
#lfw_dataset train directory
lfw_dataset_train_dir = "/content/drive/MyDrive/lfw-dataset/train"
#load lfw_dataset training images
train_dataset = keras.utils.image_dataset_from_directory(
    lfw_dataset_train_dir, label_mode=None, image_size=(IMG_SIZE, IMG_SIZE), batch_size=BATCH_SIZE
)
#normalize images
train_dataset = train_dataset.map(lambda x: x / 255.0)

#lfw_dataset test directory
lfw_dataset_test_dir = "/content/drive/MyDrive/lfw-dataset/test"
#load lfw_dataset training images
test_dataset = keras.utils.image_dataset_from_directory(
    lfw_dataset_test_dir, label_mode=None, image_size=(IMG_SIZE, IMG_SIZE), batch_size=TEST_BATCH_SIZE
)
#normalize images
test_dataset = test_dataset.map(lambda x: x / 255.0)

print()

#cross entropy loss
cross_entropy = tf.keras.losses.BinaryCrossentropy(from_logits=True)

#define generator and discriminator optimizers
#Adam with learning rate .0002 as described in paper
generator_optimizer = tf.keras.optimizers.Adam(.0002)
discriminator_optimizer = tf.keras.optimizers.Adam(.0002)

#assemble generator
generator = make_generator_model()
#assemble discriminator
discriminator = make_discriminator_model()

#train combined DCGAN
history = train(train_dataset, EPOCHS)

#save generator weights; please change to appropriate path if retraining
generator.save_weights('/content/sample_data/lfw_dataset_generator.weights.h5')
#save discriminator weights; please change to appropriate path if retraining
discriminator.save_weights('/content/sample_data/lfw_dataset_discriminator.weights.h5')

#obtain ending losses
lfw_dataset_g_loss_final = history[0][-1]
lfw_dataset_d_loss_final = history[1][-1]

#print ending losses
print()
print("LFW dataset final losses:")
print("Generator: "+str(lfw_dataset_g_loss_final))
print("Discriminator: "+str(lfw_dataset_d_loss_final))
print()

#save training curves
lfw_dataset_training_curves = history

#plot training loss for generator and discriminator
epoch_indexes = [idx+1 for idx in range(EPOCHS)]
plt.plot(epoch_indexes,history[0],label='Generator Loss')
plt.plot(epoch_indexes,history[1],label='Discriminator Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title("LFW dataset\nGenerator vs discriminator loss")
plt.legend()
plt.show()
plt.clf()

test_generated_images = []

#generate test images using trained model
for i in range(TEST_BATCH_SIZE):
    test_noise = tf.random.normal([test_size//TEST_BATCH_SIZE, noise_dim])
    generated_images = generator(test_noise, training=False).numpy()
    formatted_images = []
    for img in generated_images:
        reshaped = np.reshape(img,(1,64,64,3))
        formatted_images.append(format_image(reshaped))
    test_generated_images.append(formatted_images)

test_generated_images = np.asarray(test_generated_images)
test_real_images = np.asarray([img.numpy() for img in test_dataset])
test_real_images = np.clip(test_real_images,0.0,255.0)

#obtain lfw_dataset metrics
lfw_dataset_metrics = metrics(test_generated_images,test_real_images)
lfw_dataset_avg_IS_score = float(lfw_dataset_metrics[0])
lfw_dataset_FID_score = lfw_dataset_metrics[2]
lfw_dataset_SSIM_score = lfw_dataset_metrics[3]
lfw_dataset_PSNR_score = lfw_dataset_metrics[4]

#print lfw_dataset metrics
print("LFW dataset metrics:")
print("IS score: "+str(lfw_dataset_avg_IS_score))
print("FID score: "+str(lfw_dataset_FID_score))
print("SSIM score: "+str(lfw_dataset_SSIM_score))
print("PSNR score: "+str(lfw_dataset_PSNR_score))
# Out:
# Found 10000 files.
# Found 3000 files.
# /usr/local/lib/python3.11/dist-packages/keras/src/backend/tensorflow/nn.py:780: UserWarning: "`binary_crossentropy` received `from_logits=True`, but the `output` argument was produced by a Sigmoid activation and thus does not represent logits. Was this intended?
#   output, from_logits = _get_logits(
# Epoch 1: Generator loss: 2.722061; Discriminator loss: 0.3863989; duration: 163 seconds
# Epoch 2: Generator loss: 3.7826686; Discriminator loss: 0.11968202; duration: 11 seconds
# Epoch 3: Generator loss: 4.353534; Discriminator loss: 0.21248591; duration: 11 seconds
# Epoch 4: Generator loss: 4.677888; Discriminator loss: 0.20758572; duration: 11 seconds
# Epoch 5: Generator loss: 4.6514783; Discriminator loss: 0.20074609; duration: 11 seconds
# Epoch 6: Generator loss: 4.7695255; Discriminator loss: 0.26885444; duration: 11 seconds
# Epoch 7: Generator loss: 5.328745; Discriminator loss: 0.115317546; duration: 11 seconds
# Epoch 8: Generator loss: 4.8216376; Discriminator loss: 0.22219521; duration: 11 seconds
# Epoch 9: Generator loss: 5.337719; Discriminator loss: 0.14545225; duration: 11 seconds
# Epoch 10: Generator loss: 6.1081805; Discriminator loss: 0.069014125; duration: 11 seconds
# Epoch 11: Generator loss: 6.425943; Discriminator loss: 0.17786235; duration: 11 seconds
# Epoch 12: Generator loss: 5.776302; Discriminator loss: 0.15864429; duration: 11 seconds
# Epoch 13: Generator loss: 5.592125; Discriminator loss: 0.1077414; duration: 11 seconds
# Epoch 14: Generator loss: 5.917433; Discriminator loss: 0.1064504; duration: 11 seconds
# Epoch 15: Generator loss: 6.800172; Discriminator loss: 0.08492776; duration: 11 seconds
# Epoch 16: Generator loss: 6.1077476; Discriminator loss: 0.10362091; duration: 11 seconds
# Epoch 17: Generator loss: 7.4251595; Discriminator loss: 0.06931162; duration: 11 seconds
# Epoch 18: Generator loss: 6.6580257; Discriminator loss: 0.079959616; duration: 11 seconds
# Epoch 19: Generator loss: 6.048791; Discriminator loss: 0.072274856; duration: 11 seconds
# Epoch 20: Generator loss: 6.7915297; Discriminator loss: 0.07564701; duration: 11 seconds
# Epoch 21: Generator loss: 7.3133163; Discriminator loss: 0.07283923; duration: 11 seconds
# Epoch 22: Generator loss: 7.2003617; Discriminator loss: 0.10573924; duration: 11 seconds
# Epoch 23: Generator loss: 6.7975407; Discriminator loss: 0.08164949; duration: 11 seconds
# Epoch 24: Generator loss: 7.0824466; Discriminator loss: 0.043518595; duration: 11 seconds
# Epoch 25: Generator loss: 8.083022; Discriminator loss: 0.07441652; duration: 11 seconds
# Epoch 26: Generator loss: 7.608766; Discriminator loss: 0.07060506; duration: 11 seconds
# Epoch 27: Generator loss: 8.068788; Discriminator loss: 0.052013993; duration: 11 seconds
# Epoch 28: Generator loss: 8.060183; Discriminator loss: 0.066982284; duration: 11 seconds
# Epoch 29: Generator loss: 7.629917; Discriminator loss: 0.06896859; duration: 11 seconds
# Epoch 30: Generator loss: 7.3393946; Discriminator loss: 0.03683073; duration: 11 seconds
# Epoch 31: Generator loss: 9.529953; Discriminator loss: 0.04184568; duration: 11 seconds
# Epoch 32: Generator loss: 8.852099; Discriminator loss: 0.05997527; duration: 11 seconds
# Epoch 33: Generator loss: 8.628029; Discriminator loss: 0.039692976; duration: 11 seconds
# Epoch 34: Generator loss: 8.414299; Discriminator loss: 0.029636012; duration: 11 seconds
# Epoch 35: Generator loss: 12.224149; Discriminator loss: 0.04738455; duration: 11 seconds
# Epoch 36: Generator loss: 9.297133; Discriminator loss: 0.030548872; duration: 11 seconds
# Epoch 37: Generator loss: 9.048982; Discriminator loss: 0.041132167; duration: 11 seconds
# Epoch 38: Generator loss: 8.805109; Discriminator loss: 0.03589276; duration: 11 seconds
# Epoch 39: Generator loss: 9.610447; Discriminator loss: 0.03974898; duration: 11 seconds
# Epoch 40: Generator loss: 9.374706; Discriminator loss: 0.028348403; duration: 11 seconds
# Epoch 41: Generator loss: 9.06904; Discriminator loss: 0.03729346; duration: 11 seconds
# Epoch 42: Generator loss: 8.945021; Discriminator loss: 0.027015079; duration: 11 seconds
# Epoch 43: Generator loss: 8.759992; Discriminator loss: 0.03454882; duration: 11 seconds
# Epoch 44: Generator loss: 11.022569; Discriminator loss: 0.03891375; duration: 11 seconds
# Epoch 45: Generator loss: 8.69479; Discriminator loss: 0.03556761; duration: 11 seconds
# Epoch 46: Generator loss: 8.620842; Discriminator loss: 0.034111165; duration: 11 seconds
# Epoch 47: Generator loss: 10.319294; Discriminator loss: 0.038138248; duration: 11 seconds
# Epoch 48: Generator loss: 11.101668; Discriminator loss: 0.03063463; duration: 11 seconds
# Epoch 49: Generator loss: 10.163055; Discriminator loss: 0.029340388; duration: 11 seconds
# Epoch 50: Generator loss: 11.706143; Discriminator loss: 0.05069705; duration: 11 seconds
# Epoch 51: Generator loss: 11.041479; Discriminator loss: 0.029174453; duration: 11 seconds
# Epoch 52: Generator loss: 11.568223; Discriminator loss: 0.025306735; duration: 11 seconds
# Epoch 53: Generator loss: 10.511815; Discriminator loss: 0.024507748; duration: 11 seconds
# Epoch 54: Generator loss: 9.447478; Discriminator loss: 0.025351793; duration: 11 seconds
# Epoch 55: Generator loss: 10.965971; Discriminator loss: 0.030976444; duration: 11 seconds
# Epoch 56: Generator loss: 10.592696; Discriminator loss: 0.02188861; duration: 11 seconds
# Epoch 57: Generator loss: 11.151441; Discriminator loss: 0.022262242; duration: 11 seconds
# Epoch 58: Generator loss: 9.976796; Discriminator loss: 0.020823624; duration: 11 seconds
# Epoch 59: Generator loss: 9.923308; Discriminator loss: 0.027734183; duration: 11 seconds
# Epoch 60: Generator loss: 10.63122; Discriminator loss: 0.024758033; duration: 11 seconds
# Epoch 61: Generator loss: 9.949403; Discriminator loss: 0.0116395755; duration: 11 seconds
# Epoch 62: Generator loss: 11.903202; Discriminator loss: 0.02410625; duration: 11 seconds
# Epoch 63: Generator loss: 11.546347; Discriminator loss: 0.029525416; duration: 11 seconds
# Epoch 64: Generator loss: 10.866576; Discriminator loss: 0.02278969; duration: 11 seconds
# Epoch 65: Generator loss: 10.442895; Discriminator loss: 0.021944446; duration: 11 seconds
# Epoch 66: Generator loss: 11.641278; Discriminator loss: 0.022021852; duration: 11 seconds
# Epoch 67: Generator loss: 13.53794; Discriminator loss: 0.041061096; duration: 11 seconds
# Epoch 68: Generator loss: 11.482015; Discriminator loss: 0.026334422; duration: 11 seconds
# Epoch 69: Generator loss: 10.684362; Discriminator loss: 0.025551941; duration: 11 seconds
# Epoch 70: Generator loss: 10.669939; Discriminator loss: 0.020433167; duration: 11 seconds
# Epoch 71: Generator loss: 11.847586; Discriminator loss: 0.026003202; duration: 11 seconds
# Epoch 72: Generator loss: 12.145744; Discriminator loss: 0.027692934; duration: 11 seconds
# Epoch 73: Generator loss: 9.165752; Discriminator loss: 0.01918653; duration: 11 seconds
# Epoch 74: Generator loss: 9.711243; Discriminator loss: 0.017672198; duration: 11 seconds
# Epoch 75: Generator loss: 12.2411375; Discriminator loss: 0.041222926; duration: 11 seconds
# Epoch 76: Generator loss: 12.69619; Discriminator loss: 0.056459486; duration: 11 seconds
# Epoch 77: Generator loss: 11.057608; Discriminator loss: 0.043669134; duration: 11 seconds
# Epoch 78: Generator loss: 8.710351; Discriminator loss: 0.024293348; duration: 11 seconds
# Epoch 79: Generator loss: 8.545455; Discriminator loss: 0.017309258; duration: 11 seconds
# Epoch 80: Generator loss: 9.871159; Discriminator loss: 0.019749463; duration: 11 seconds
# Epoch 81: Generator loss: 15.183524; Discriminator loss: 0.045958888; duration: 11 seconds
# Epoch 82: Generator loss: 12.157143; Discriminator loss: 0.031346742; duration: 11 seconds
# Epoch 83: Generator loss: 11.489285; Discriminator loss: 0.022798229; duration: 11 seconds
# Epoch 84: Generator loss: 14.585925; Discriminator loss: 0.028624201; duration: 11 seconds
# Epoch 85: Generator loss: 10.711504; Discriminator loss: 0.02047355; duration: 11 seconds
# Epoch 86: Generator loss: 11.917626; Discriminator loss: 0.026918411; duration: 11 seconds
# Epoch 87: Generator loss: 11.977996; Discriminator loss: 0.041971803; duration: 11 seconds
# Epoch 88: Generator loss: 10.911579; Discriminator loss: 0.024293337; duration: 11 seconds
# Epoch 89: Generator loss: 12.932838; Discriminator loss: 0.036000837; duration: 11 seconds
# Epoch 90: Generator loss: 12.074995; Discriminator loss: 0.020794854; duration: 11 seconds
# Epoch 91: Generator loss: 10.839895; Discriminator loss: 0.014962355; duration: 11 seconds
# Epoch 92: Generator loss: 9.849333; Discriminator loss: 0.026449434; duration: 11 seconds
# Epoch 93: Generator loss: 10.9439125; Discriminator loss: 0.020542033; duration: 11 seconds
# Epoch 94: Generator loss: 9.724439; Discriminator loss: 0.01864575; duration: 11 seconds
# Epoch 95: Generator loss: 12.487816; Discriminator loss: 0.016330011; duration: 11 seconds
# Epoch 96: Generator loss: 11.899562; Discriminator loss: 0.032941718; duration: 11 seconds
# Epoch 97: Generator loss: 14.220524; Discriminator loss: 0.033793807; duration: 11 seconds
# Epoch 98: Generator loss: 13.6795; Discriminator loss: 0.033853233; duration: 11 seconds
# Epoch 99: Generator loss: 11.543202; Discriminator loss: 0.024181198; duration: 11 seconds
# Epoch 100: Generator loss: 16.396917; Discriminator loss: 0.07397792; duration: 11 seconds
# Epoch 101: Generator loss: 12.253631; Discriminator loss: 0.02852491; duration: 11 seconds
# Epoch 102: Generator loss: 13.4550085; Discriminator loss: 0.033854067; duration: 11 seconds
# Epoch 103: Generator loss: 11.663682; Discriminator loss: 0.025702858; duration: 11 seconds
# Epoch 104: Generator loss: 11.485505; Discriminator loss: 0.017960114; duration: 11 seconds
# Epoch 105: Generator loss: 10.472709; Discriminator loss: 0.020211155; duration: 11 seconds
# Epoch 106: Generator loss: 12.419399; Discriminator loss: 0.04100243; duration: 11 seconds
# Epoch 107: Generator loss: 11.204268; Discriminator loss: 0.033990506; duration: 11 seconds
# Epoch 108: Generator loss: 12.357242; Discriminator loss: 0.03391875; duration: 11 seconds
# Epoch 109: Generator loss: 14.320658; Discriminator loss: 0.04187819; duration: 11 seconds
# Epoch 110: Generator loss: 10.624789; Discriminator loss: 0.033683468; duration: 11 seconds
# Epoch 111: Generator loss: 9.556071; Discriminator loss: 0.019772226; duration: 11 seconds
# Epoch 112: Generator loss: 9.437731; Discriminator loss: 0.02241603; duration: 11 seconds
# Epoch 113: Generator loss: 10.2315645; Discriminator loss: 0.02415761; duration: 11 seconds
# Epoch 114: Generator loss: 10.437063; Discriminator loss: 0.014465984; duration: 11 seconds
# Epoch 115: Generator loss: 10.287489; Discriminator loss: 0.021504208; duration: 11 seconds
# Epoch 116: Generator loss: 14.95459; Discriminator loss: 0.04123677; duration: 11 seconds
# Epoch 117: Generator loss: 11.187742; Discriminator loss: 0.028747717; duration: 11 seconds
# Epoch 118: Generator loss: 18.816174; Discriminator loss: 0.049247175; duration: 11 seconds
# Epoch 119: Generator loss: 13.280986; Discriminator loss: 0.02458659; duration: 11 seconds
# Epoch 120: Generator loss: 11.663577; Discriminator loss: 0.018102374; duration: 11 seconds
# Epoch 121: Generator loss: 11.128847; Discriminator loss: 0.015205497; duration: 11 seconds
# Epoch 122: Generator loss: 16.77275; Discriminator loss: 0.05777568; duration: 11 seconds
# Epoch 123: Generator loss: 10.679829; Discriminator loss: 0.023232268; duration: 11 seconds
# Epoch 124: Generator loss: 10.9135275; Discriminator loss: 0.01972759; duration: 11 seconds
# Epoch 125: Generator loss: 10.076574; Discriminator loss: 0.015944295; duration: 11 seconds
# Epoch 126: Generator loss: 10.258881; Discriminator loss: 0.012146006; duration: 11 seconds
# Epoch 127: Generator loss: 11.558118; Discriminator loss: 0.02688724; duration: 11 seconds
# Epoch 128: Generator loss: 13.314772; Discriminator loss: 0.033032697; duration: 11 seconds
# Epoch 129: Generator loss: 12.466483; Discriminator loss: 0.015249115; duration: 11 seconds
# Epoch 130: Generator loss: 10.308854; Discriminator loss: 0.011953168; duration: 11 seconds
# Epoch 131: Generator loss: 15.557994; Discriminator loss: 0.03151623; duration: 11 seconds
# Epoch 132: Generator loss: 12.239067; Discriminator loss: 0.017983906; duration: 11 seconds
# Epoch 133: Generator loss: 15.054996; Discriminator loss: 0.024755094; duration: 11 seconds
# Epoch 134: Generator loss: 12.184376; Discriminator loss: 0.014249821; duration: 11 seconds
# Epoch 135: Generator loss: 12.134485; Discriminator loss: 0.010004021; duration: 11 seconds
# Epoch 136: Generator loss: 15.50258; Discriminator loss: 0.038180914; duration: 11 seconds
# Epoch 137: Generator loss: 9.741316; Discriminator loss: 0.01635603; duration: 11 seconds
# Epoch 138: Generator loss: 12.109765; Discriminator loss: 0.026038103; duration: 11 seconds
# Epoch 139: Generator loss: 11.909881; Discriminator loss: 0.013284616; duration: 11 seconds
# Epoch 140: Generator loss: 13.358561; Discriminator loss: 0.019210001; duration: 11 seconds
# Epoch 141: Generator loss: 10.917347; Discriminator loss: 0.012821574; duration: 11 seconds
# Epoch 142: Generator loss: 11.555483; Discriminator loss: 0.011518791; duration: 11 seconds
# Epoch 143: Generator loss: 14.128849; Discriminator loss: 0.017766284; duration: 11 seconds
# Epoch 144: Generator loss: 12.573896; Discriminator loss: 0.0171604; duration: 11 seconds
# Epoch 145: Generator loss: 16.242731; Discriminator loss: 0.026192555; duration: 11 seconds
# Epoch 146: Generator loss: 14.081338; Discriminator loss: 0.019876668; duration: 11 seconds
# Epoch 147: Generator loss: 12.987616; Discriminator loss: 0.010868888; duration: 11 seconds
# Epoch 148: Generator loss: 11.37152; Discriminator loss: 0.013591423; duration: 11 seconds
# Epoch 149: Generator loss: 12.9572315; Discriminator loss: 0.011974086; duration: 11 seconds
# Epoch 150: Generator loss: 18.4534; Discriminator loss: 0.11467132; duration: 11 seconds
# LFW dataset final losses:
# Generator: 18.4534
# Discriminator: 0.11467132
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_v3/inception_v3_weights_tf_dim_ordering_tf_kernels.h5
# 96112376/96112376 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_v3/inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5
# 87910968/87910968 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# WARNING:tensorflow:5 out of the last 17 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7c22fe006f20> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:5 out of the last 11 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7c23425ada80> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# LFW dataset metrics:
# IS score: 1.0007137060165405
# FID score: 390.63255158509975
# SSIM score: 0.97062653
# PSNR score: 6.481910629519756
