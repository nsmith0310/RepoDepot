# %% [markdown]
# The following cell defines all central functions needed for training the SA_SN_DCGAN, computing metrics, and displaying images.

# %%
#imports
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import keras
from keras import layers, activations
from keras.initializers import RandomNormal
from keras.applications import InceptionV3
from keras.applications.inception_v3 import preprocess_input
import matplotlib.pyplot as plt
import cv2
from skimage.transform import resize
from scipy.linalg import sqrtm
import numpy as np
import os, time
from skimage.metrics import structural_similarity, peak_signal_noise_ratio

#Inception (IS) score metric
def IS_score(image_list, n_split=10, epsilon=1E-16):
    model = InceptionV3()
    scores = []
    n_partition = image_list.shape[0]//n_split
    for idx in range(n_split):
        subset = image_list[idx*n_partition:(idx+1)*n_partition].astype('float32')
        subset = np.asarray([resize(image, (299,299,3), 0) for image in subset])
        subset = preprocess_input(subset)
        prediction_yx = model.predict(subset,verbose=0)
        prediction_y = np.expand_dims(prediction_yx.mean(axis=0), 0)
        KL_div = prediction_yx * (np.log(prediction_yx + epsilon) - np.log(prediction_y + epsilon))
        sum_KL_div = KL_div.sum(axis=1)
        avg_KL_div = np.mean(sum_KL_div)
        is_score = np.exp(avg_KL_div)
        scores.append(is_score)
    avg_IS,stdv_IS = np.mean(scores),np.std(scores)
    return avg_IS,stdv_IS

#FID score metric
def FID_score(images_1, images_2):
    model = InceptionV3(include_top=False, pooling='avg', input_shape=(299,299,3))
    images_1 = np.asarray([resize(image, (299,299,3), 0) for image in images_1])
    images_2 = np.asarray([resize(image, (299,299,3), 0) for image in images_2])
    activation_1,activation_2 = model.predict(images_1,verbose=0),model.predict(images_2,verbose=0)
    mu_1, sigma_1 = activation_1.mean(axis=0), np.cov(activation_1, rowvar=False)
    mu_2, sigma_2 = activation_2.mean(axis=0), np.cov(activation_2, rowvar=False)
    ss_difference = np.sum((mu_1-mu_2)**2.0)
    covariance_mean = sqrtm(sigma_1.dot(sigma_2))
    if np.iscomplexobj(covariance_mean):covariance_mean=covariance_mean.real
    fid_score = ss_difference + np.trace(sigma_1 + sigma_2 - 2.0*covariance_mean)
    return fid_score

#SSIM metric
def SSIM(images_1,images_2):
    total_SSIM = sum([structural_similarity(images_1[idx],images_2[idx],
                                            channel_axis=-1, data_range=255.0) for idx in range(len(images_1))])
    return total_SSIM/len(images_1)

#PSNR metric
def PSNR(images_1,images_2):
    total_PSNR = sum([peak_signal_noise_ratio(images_1[idx],images_2[idx]) for idx in range(len(images_1))])
    return total_PSNR/len(images_1)

#metrics helper function
def metrics(images_1,images_2):
    batch_size = len(images_2)

    total_avg_IS_score = 0
    total_std_IS_score = 0
    total_FID_score = 0
    total_SSIM_score = 0
    total_PSNR_score = 0

    #compute IS score averaged over batch size
    for idx in range(batch_size):
        avg,std = IS_score(images_1[idx])
        total_avg_IS_score+=avg
        total_std_IS_score+=std
    total_avg_IS_score/=batch_size
    total_std_IS_score/=batch_size

    #compute FID score averaged over batch size
    for idx in range(batch_size):
        total_FID_score+=FID_score(images_1[idx],images_2[idx])
    total_FID_score/=batch_size

    #compute SSIM score averaged over batch size
    for idx in range(batch_size):
        total_SSIM_score+=SSIM(images_1[idx],images_2[idx])
    total_SSIM_score/=batch_size

    #compute PSNR score averaged over batch size
    for idx in range(batch_size):
        total_PSNR_score+=PSNR(images_1[idx],images_2[idx])
    total_PSNR_score/=batch_size

    return total_avg_IS_score,total_std_IS_score,total_FID_score,total_SSIM_score,total_PSNR_score

#format generator output for display
def format_image(generator_output):
    unscaled_image = generator_output[0,:,:,:]
    scaled_image = (generator_output*127.5)+127.5
    clipped_image = np.clip(scaled_image,0.0,255.0)
    clipped_image/=255.0
    return clipped_image[0]

#display 9 images at once
def display_images():

    for idx in range(1,10):
        plt.subplot(3,3,idx)
        noise = tf.random.normal([1, 100])
        generated_image = generator(noise, training=False)
        img = format_image(generated_image)
        plt.imshow(img)
        plt.axis('off')
    plt.show()
    plt.clf()

#make generator following architecture outlined in paper
def make_generator_model():

    #input layer takes noise vector
    input_layer = keras.Input(shape=(100,))

    #fully connected layer without bias or activation to reshape input
    fcl = layers.Dense(4*4*3, use_bias=False,name='fcl')(input_layer)

    #reshape fully connected output
    reshape = layers.Reshape((4, 4, 3),name='reshape')(fcl)

    #transpose convolution block 1 using 512 filters, (mu=0,std=.02) normal initialization, batch normalization, and relu activation
    tconv1 = layers.Conv2DTranspose(512,3,padding='same',kernel_initializer=RandomNormal(mean=0.0, stddev=0.02),name='tconv1')(reshape)
    bnorm1 = layers.BatchNormalization()(tconv1)
    relu1 = layers.Activation(activations.relu)(bnorm1)

    #transpose convolution block 2 using 256 filters, (mu=0,std=.02) normal initialization, batch normalization, and relu activation
    tconv2 = layers.Conv2DTranspose(256,3,strides=2,padding='same',kernel_initializer=RandomNormal(mean=0.0, stddev=0.02),name='tconv2')(relu1)
    bnorm2 = layers.BatchNormalization()(tconv2)
    relu2 = layers.Activation(activations.relu)(bnorm2)

    #self attention layer
    attention = layers.MultiHeadAttention(1,256,kernel_initializer=RandomNormal(mean=0.0, stddev=0.02),name='attention')(relu2,relu2)

    #transpose convolution block 3 using 128 filters, (mu=0,std=.02) normal initialization, batch normalization, and relu activation
    tconv3 = layers.Conv2DTranspose(128,3,strides=2,padding='same',kernel_initializer=RandomNormal(mean=0.0, stddev=0.02),name='tconv3')(attention)
    bnorm3 = layers.BatchNormalization()(tconv3)
    relu3 = layers.Activation(activations.relu)(bnorm3)

    #transpose convolution block 4 using 64 filters, (mu=0,std=.02) normal initialization, batch normalization, and relu activation
    tconv4 = layers.Conv2DTranspose(64,3,strides=2,padding='same',kernel_initializer=RandomNormal(mean=0.0, stddev=0.02),name='tconv4')(tconv3)
    bnorm4 = layers.BatchNormalization()(tconv4)
    relu4 = layers.Activation(activations.relu)(bnorm4)

    #transpose convolution block 5 (output layer) using 3 filters, (mu=0,std=.02) normal initialization, batch normalization, and relu activation
    output_layer = layers.Conv2DTranspose(3,3,strides=2,padding='same',kernel_initializer=RandomNormal(mean=0.0, stddev=0.02),activation='tanh',name='output')(relu4)

    #assemble model
    model = keras.Model(inputs=input_layer, outputs=output_layer,name='generator')

    return model

#make discriminator following architecture outlined in paper
def make_discriminator_model():

    #input layer taking output from discriminator
    input_layer = keras.Input(shape=[64, 64, 3])

    #spectral normalization layer with 64 filters and leaky relu activation
    spec_norm = layers.SpectralNormalization(layers.Conv2D(64,3,strides=2,padding='same',name='spec_norm'))(input_layer)
    lrelu1 = layers.LeakyReLU(name='lrelu1')(spec_norm)

    #convolutional block 1 with 128 filters and leaky relu activation
    conv1 = layers.Conv2D(128,3,strides=2,padding='same',name='conv1')(lrelu1)
    bnorm1 = layers.BatchNormalization()(conv1)
    lrelu2 = layers.LeakyReLU(name='lrelu2')(bnorm1)

    #convolutional block 2 with 256 filters and leaky relu activation
    conv2 = layers.Conv2D(256,3,strides=2,padding='same',name='conv2')(lrelu2)
    bnorm2 = layers.BatchNormalization()(conv2)
    lrelu3 = layers.LeakyReLU(name='lrelu3')(conv2)

    #convolutional block 3 with 512 filters and leaky relu activation
    conv3 = layers.Conv2D(512,3,strides=2,padding='same',name='conv3')(lrelu3)
    bnorm3 = layers.BatchNormalization()(conv3)
    lrelu4 = layers.LeakyReLU(name='lrelu4')(conv3)

    #flatten convolutional block output
    flattened = layers.Flatten()(lrelu4)

    #spectral normalization output layer with (mu=0,std=.02) normal initialization, one unit and sigmoid activation (binary classification for real vs fake)
    output_layer = layers.SpectralNormalization(layers.Dense(1,kernel_initializer=RandomNormal(mean=0.0, stddev=0.02),activation='sigmoid',name='output_layer'))(flattened)

    #assemble model
    model = keras.Model(inputs=input_layer,outputs=output_layer,name='discriminator')

    return model

#discriminator loss takes real output (real images) and fake output (generator output)
#real output and fake output are the discriminators decisions on sets of real and fake images
def discriminator_loss(real_output, fake_output):

    #real loss is how far discriminator is from classifying real output from 1
    real_loss = cross_entropy(tf.ones_like(real_output), real_output)

    #fake loss is how far discriminator is from classifying fake output from 0
    fake_loss = cross_entropy(tf.zeros_like(fake_output), fake_output)

    #total discriminator loss is the sum of both losses
    total_loss = real_loss + fake_loss
    return total_loss

#generator loss takes fake output (the decisions from the descriminator on fake images)
def generator_loss(fake_output):
    #loss is how far the generator was from tricking the discriminator
    return cross_entropy(tf.ones_like(fake_output), fake_output)

#training function
@tf.function
def train_step(images):
    #generate batch of noise samples for the generator
    noise = tf.random.normal([BATCH_SIZE, noise_dim])

    with tf.GradientTape() as gen_tape, tf.GradientTape() as disc_tape:
        #get fake images from generator
        generated_images = generator(noise, training=True)
        #get classifications from discriminator on real images
        real_output = discriminator(images, training=True)
        #get classifications from discriminator on fake images
        fake_output = discriminator(generated_images, training=True)
        #get generator loss using discriminators decisions on its output
        g_loss = generator_loss(fake_output)
        d_loss = discriminator_loss(real_output, fake_output)
        #get discriminator loss based on how well it discerned real from fake
    #get gradients of the generator
    gradients_of_generator = gen_tape.gradient(g_loss, generator.trainable_variables)
    #get gradients of the discriminator
    gradients_of_discriminator = disc_tape.gradient(d_loss, discriminator.trainable_variables)

    #update generator weights
    generator_optimizer.apply_gradients(zip(gradients_of_generator, generator.trainable_variables))
    #update discriminator weights
    discriminator_optimizer.apply_gradients(zip(gradients_of_discriminator, discriminator.trainable_variables))

    return g_loss, d_loss

#training function
def train(dataset, epochs):
    losses = [[],[]]

    #for each epoch, apply train step and save generator and discriminator loss; time epoch
    for epoch in range(1,epochs+1):
        start_time = time.time()
        g_losses = []
        d_losses = []
        for image_batch in dataset:
            g_loss,d_loss = train_step(image_batch)
            g_losses.append(g_loss)
            d_losses.append(d_loss)
        losses[0].append(tf.math.reduce_mean(g_losses).numpy())
        losses[1].append(tf.math.reduce_mean(d_losses).numpy())
        epoch_time = round(time.time() - start_time)

        #display epoch information (time and losses)
        print("Epoch "+str(epoch)+": Generator loss: "+str(losses[0][-1])+"; Discriminator loss: "
              +str(losses[1][-1])+"; duration: "+str(epoch_time)+" seconds")

        #periodically display images following numbers in paper
        if (epoch==10 or epoch%50==0):
            print()
            display_images()
            print()

    return losses

#training and testing parameters
BATCH_SIZE = 64
IMG_SIZE = 64
TEST_BATCH_SIZE = 100
EPOCHS = 150
noise_dim = 100
test_size = 10000

# %% [markdown]
# The following cell defines the training loop and evaluation on iCartoonFace

# %%
#iCartoonFace dataset train directory
iCartoonFace_train_dir = "/content/drive/MyDrive/iCartoonFace/train"
#load iCartoonFace dataset training images
train_dataset = keras.utils.image_dataset_from_directory(
    iCartoonFace_train_dir, label_mode=None, image_size=(IMG_SIZE, IMG_SIZE), batch_size=BATCH_SIZE
)
#normalize images
train_dataset = train_dataset.map(lambda x: x / 255.0)

#iCartoonFace dataset test directory
iCartoonFace_test_dir = "/content/drive/MyDrive/iCartoonFace/test"
#load iCartoonFace dataset training images
test_dataset = keras.utils.image_dataset_from_directory(
    iCartoonFace_test_dir, label_mode=None, image_size=(IMG_SIZE, IMG_SIZE), batch_size=TEST_BATCH_SIZE
)
#normalize images
test_dataset = test_dataset.map(lambda x: x / 255.0)

print()

#cross entropy loss
cross_entropy = tf.keras.losses.BinaryCrossentropy(from_logits=True)

#define generator and discriminator optimizers
#Adam with learning rate .0002 as described in paper
generator_optimizer = tf.keras.optimizers.Adam(.0002)
discriminator_optimizer = tf.keras.optimizers.Adam(.0002)

#assemble generator
generator = make_generator_model()
#assemble discriminator
discriminator = make_discriminator_model()

#train combined DCGAN
history = train(train_dataset, EPOCHS)

#save generator weights; please change to appropriate path if retraining
generator.save_weights('/content/sample_data/iCartoonFace_generator.weights.h5')
#save discriminator weights; please change to appropriate path if retraining
discriminator.save_weights('/content/sample_data/iCartoonFace_discriminator.weights.h5')

#obtain ending losses
iCartoonFace_g_loss_final = history[0][-1]
iCartoonFace_d_loss_final = history[1][-1]

#print ending losses
print()
print("iCartoonFace dataset final losses:")
print("Generator: "+str(iCartoonFace_g_loss_final))
print("Discriminator: "+str(iCartoonFace_d_loss_final))
print()

#save training curves
iCartoonFace_training_curves = history

#plot training loss for generator and discriminator
epoch_indexes = [idx+1 for idx in range(EPOCHS)]
plt.plot(epoch_indexes,history[0],label='Generator Loss')
plt.plot(epoch_indexes,history[1],label='Discriminator Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title("iCartoonFace dataset\nGenerator vs discriminator loss")
plt.legend()
plt.show()
plt.clf()

test_generated_images = []

#generate test images using trained model
for i in range(TEST_BATCH_SIZE):
    test_noise = tf.random.normal([test_size//TEST_BATCH_SIZE, noise_dim])
    generated_images = generator(test_noise, training=False).numpy()
    formatted_images = []
    for img in generated_images:
        reshaped = np.reshape(img,(1,64,64,3))
        formatted_images.append(format_image(reshaped))
    test_generated_images.append(formatted_images)

test_generated_images = np.asarray(test_generated_images)
test_real_images = np.asarray([img.numpy() for img in test_dataset])
test_real_images = np.clip(test_real_images,0.0,255.0)

#obtain iCartoonFace metrics
iCartoonFace_metrics = metrics(test_generated_images,test_real_images)
iCartoonFace_avg_IS_score = float(iCartoonFace_metrics[0])
iCartoonFace_FID_score = iCartoonFace_metrics[2]
iCartoonFace_SSIM_score = iCartoonFace_metrics[3]
iCartoonFace_PSNR_score = iCartoonFace_metrics[4]

#print iCartoonFace metrics
print("iCartoonFace dataset metrics:")
print("IS score: "+str(iCartoonFace_avg_IS_score))
print("FID score: "+str(iCartoonFace_FID_score))
print("SSIM score: "+str(iCartoonFace_SSIM_score))
print("PSNR score: "+str(iCartoonFace_PSNR_score))
# Out:
# Found 30000 files.
# Found 10000 files.
# /usr/local/lib/python3.11/dist-packages/keras/src/backend/tensorflow/nn.py:780: UserWarning: "`binary_crossentropy` received `from_logits=True`, but the `output` argument was produced by a Sigmoid activation and thus does not represent logits. Was this intended?
#   output, from_logits = _get_logits(
# Epoch 1: Generator loss: 3.1408331; Discriminator loss: 0.44426328; duration: 1539 seconds
# Epoch 2: Generator loss: 3.2345388; Discriminator loss: 0.48628128; duration: 38 seconds
# Epoch 3: Generator loss: 3.1268253; Discriminator loss: 0.4932596; duration: 37 seconds
# Epoch 4: Generator loss: 3.8583407; Discriminator loss: 0.44014212; duration: 38 seconds
# Epoch 5: Generator loss: 3.9464016; Discriminator loss: 0.33690333; duration: 38 seconds
# Epoch 6: Generator loss: 5.043334; Discriminator loss: 0.21528673; duration: 37 seconds
# Epoch 7: Generator loss: 5.3972754; Discriminator loss: 0.22607878; duration: 37 seconds
# Epoch 8: Generator loss: 5.0932508; Discriminator loss: 0.25073984; duration: 37 seconds
# Epoch 9: Generator loss: 5.8082876; Discriminator loss: 0.19619025; duration: 37 seconds
# Epoch 10: Generator loss: 5.640593; Discriminator loss: 0.2301674; duration: 37 seconds
# Epoch 11: Generator loss: 6.220395; Discriminator loss: 0.13381732; duration: 37 seconds
# Epoch 12: Generator loss: 7.4280415; Discriminator loss: 0.10810781; duration: 37 seconds
# Epoch 13: Generator loss: 8.772516; Discriminator loss: 0.16931914; duration: 37 seconds
# Epoch 14: Generator loss: 7.642371; Discriminator loss: 0.08463508; duration: 37 seconds
# Epoch 15: Generator loss: 8.841363; Discriminator loss: 0.08725895; duration: 37 seconds
# Epoch 16: Generator loss: 8.999123; Discriminator loss: 0.06006994; duration: 37 seconds
# Epoch 17: Generator loss: 8.8426285; Discriminator loss: 0.08848707; duration: 37 seconds
# Epoch 18: Generator loss: 8.357117; Discriminator loss: 0.06805976; duration: 37 seconds
# Epoch 19: Generator loss: 12.031549; Discriminator loss: 0.095340036; duration: 37 seconds
# Epoch 20: Generator loss: 8.63252; Discriminator loss: 0.10898164; duration: 37 seconds
# Epoch 21: Generator loss: 7.9708314; Discriminator loss: 0.08502344; duration: 37 seconds
# Epoch 22: Generator loss: 9.293183; Discriminator loss: 0.116346985; duration: 37 seconds
# Epoch 23: Generator loss: 8.687347; Discriminator loss: 0.10660993; duration: 37 seconds
# Epoch 24: Generator loss: 8.338553; Discriminator loss: 0.078300826; duration: 37 seconds
# Epoch 25: Generator loss: 8.965045; Discriminator loss: 0.09813832; duration: 37 seconds
# Epoch 26: Generator loss: 9.247157; Discriminator loss: 0.09841616; duration: 37 seconds
# Epoch 27: Generator loss: 9.355398; Discriminator loss: 0.10099783; duration: 37 seconds
# Epoch 28: Generator loss: 8.752437; Discriminator loss: 0.08559811; duration: 37 seconds
# Epoch 29: Generator loss: 8.962294; Discriminator loss: 0.089697085; duration: 37 seconds
# Epoch 30: Generator loss: 9.656321; Discriminator loss: 0.11312463; duration: 37 seconds
# Epoch 31: Generator loss: 9.79935; Discriminator loss: 0.08674941; duration: 37 seconds
# Epoch 32: Generator loss: 8.801276; Discriminator loss: 0.106935896; duration: 37 seconds
# Epoch 33: Generator loss: 8.90272; Discriminator loss: 0.08437335; duration: 38 seconds
# Epoch 34: Generator loss: 9.558662; Discriminator loss: 0.099819325; duration: 37 seconds
# Epoch 35: Generator loss: 8.838815; Discriminator loss: 0.070391804; duration: 37 seconds
# Epoch 36: Generator loss: 10.285145; Discriminator loss: 0.06731487; duration: 37 seconds
# Epoch 37: Generator loss: 9.587741; Discriminator loss: 0.09282632; duration: 38 seconds
# Epoch 38: Generator loss: 11.380338; Discriminator loss: 0.09344855; duration: 37 seconds
# Epoch 39: Generator loss: 9.810515; Discriminator loss: 0.08592577; duration: 37 seconds
# Epoch 40: Generator loss: 9.871221; Discriminator loss: 0.08212768; duration: 37 seconds
# Epoch 41: Generator loss: 11.180014; Discriminator loss: 0.07747333; duration: 37 seconds
# Epoch 42: Generator loss: 9.95557; Discriminator loss: 0.07040354; duration: 37 seconds
# Epoch 43: Generator loss: 9.471373; Discriminator loss: 0.09107389; duration: 37 seconds
# Epoch 44: Generator loss: 10.672844; Discriminator loss: 0.08019875; duration: 37 seconds
# Epoch 45: Generator loss: 9.733617; Discriminator loss: 0.05478535; duration: 37 seconds
# Epoch 46: Generator loss: 10.333247; Discriminator loss: 0.051495142; duration: 37 seconds
# Epoch 47: Generator loss: 10.9838; Discriminator loss: 0.063508764; duration: 37 seconds
# Epoch 48: Generator loss: 11.172174; Discriminator loss: 0.07454988; duration: 37 seconds
# Epoch 49: Generator loss: 11.142792; Discriminator loss: 0.061877504; duration: 37 seconds
# Epoch 50: Generator loss: 11.099724; Discriminator loss: 0.09169922; duration: 37 seconds
# Epoch 51: Generator loss: 9.758384; Discriminator loss: 0.069817424; duration: 37 seconds
# Epoch 52: Generator loss: 10.678935; Discriminator loss: 0.054762833; duration: 37 seconds
# Epoch 53: Generator loss: 11.900383; Discriminator loss: 0.07122916; duration: 37 seconds
# Epoch 54: Generator loss: 11.172021; Discriminator loss: 0.05651005; duration: 37 seconds
# Epoch 55: Generator loss: 10.954554; Discriminator loss: 0.05759366; duration: 37 seconds
# Epoch 56: Generator loss: 11.481836; Discriminator loss: 0.05216415; duration: 37 seconds
# Epoch 57: Generator loss: 11.477575; Discriminator loss: 0.042352315; duration: 37 seconds
# Epoch 58: Generator loss: 12.170671; Discriminator loss: 0.058905296; duration: 37 seconds
# Epoch 59: Generator loss: 11.539781; Discriminator loss: 0.053430896; duration: 37 seconds
# Epoch 60: Generator loss: 11.48646; Discriminator loss: 0.050211415; duration: 37 seconds
# Epoch 61: Generator loss: 12.407893; Discriminator loss: 0.06031003; duration: 37 seconds
# Epoch 62: Generator loss: 12.964685; Discriminator loss: 0.068878196; duration: 38 seconds
# Epoch 63: Generator loss: 11.198756; Discriminator loss: 0.04933547; duration: 37 seconds
# Epoch 64: Generator loss: 11.355279; Discriminator loss: 0.043597955; duration: 37 seconds
# Epoch 65: Generator loss: 11.656284; Discriminator loss: 0.048123617; duration: 37 seconds
# Epoch 66: Generator loss: 12.79173; Discriminator loss: 0.044403158; duration: 37 seconds
# Epoch 67: Generator loss: 12.349715; Discriminator loss: 0.047819883; duration: 37 seconds
# Epoch 68: Generator loss: 13.424993; Discriminator loss: 0.04406046; duration: 37 seconds
# Epoch 69: Generator loss: 13.796269; Discriminator loss: 0.052575924; duration: 37 seconds
# Epoch 70: Generator loss: 11.712736; Discriminator loss: 0.039766308; duration: 37 seconds
# Epoch 71: Generator loss: 12.795636; Discriminator loss: 0.045438133; duration: 37 seconds
# Epoch 72: Generator loss: 13.785302; Discriminator loss: 0.061176956; duration: 37 seconds
# Epoch 73: Generator loss: 12.30423; Discriminator loss: 0.046045773; duration: 37 seconds
# Epoch 74: Generator loss: 12.580622; Discriminator loss: 0.045067463; duration: 37 seconds
# Epoch 75: Generator loss: 12.880105; Discriminator loss: 0.042415895; duration: 37 seconds
# Epoch 76: Generator loss: 13.860318; Discriminator loss: 0.038441677; duration: 37 seconds
# Epoch 77: Generator loss: 14.07736; Discriminator loss: 0.042871185; duration: 37 seconds
# Epoch 78: Generator loss: 14.32051; Discriminator loss: 0.03592789; duration: 37 seconds
# Epoch 79: Generator loss: 15.806675; Discriminator loss: 0.032010645; duration: 37 seconds
# Epoch 80: Generator loss: 17.703917; Discriminator loss: 0.037420627; duration: 37 seconds
# Epoch 81: Generator loss: 15.779453; Discriminator loss: 0.045458842; duration: 37 seconds
# Epoch 82: Generator loss: 13.410761; Discriminator loss: 0.023831682; duration: 37 seconds
# Epoch 83: Generator loss: 15.396373; Discriminator loss: 0.03582985; duration: 37 seconds
# Epoch 84: Generator loss: 14.471075; Discriminator loss: 0.032562356; duration: 37 seconds
# Epoch 85: Generator loss: 14.632654; Discriminator loss: 0.028563315; duration: 37 seconds
# Epoch 86: Generator loss: 15.490332; Discriminator loss: 0.045820415; duration: 37 seconds
# Epoch 87: Generator loss: 13.482694; Discriminator loss: 0.04244402; duration: 37 seconds
# Epoch 88: Generator loss: 14.610844; Discriminator loss: 0.05860923; duration: 37 seconds
# Epoch 89: Generator loss: 14.595659; Discriminator loss: 0.023408316; duration: 37 seconds
# Epoch 90: Generator loss: 14.992804; Discriminator loss: 0.030634973; duration: 37 seconds
# Epoch 91: Generator loss: 14.884586; Discriminator loss: 0.026956635; duration: 37 seconds
# Epoch 92: Generator loss: 16.534504; Discriminator loss: 0.030171892; duration: 38 seconds
# Epoch 93: Generator loss: 17.622873; Discriminator loss: 0.018839046; duration: 37 seconds
# Epoch 94: Generator loss: 15.147396; Discriminator loss: 0.03208311; duration: 37 seconds
# Epoch 95: Generator loss: 17.57574; Discriminator loss: 0.05788883; duration: 37 seconds
# Epoch 96: Generator loss: 15.027653; Discriminator loss: 0.032330997; duration: 37 seconds
# Epoch 97: Generator loss: 16.886625; Discriminator loss: 0.032295335; duration: 37 seconds
# Epoch 98: Generator loss: 15.251784; Discriminator loss: 0.022286814; duration: 37 seconds
# Epoch 99: Generator loss: 15.066839; Discriminator loss: 0.04071656; duration: 37 seconds
# Epoch 100: Generator loss: 13.131986; Discriminator loss: 0.05390568; duration: 37 seconds
# Epoch 101: Generator loss: 13.569333; Discriminator loss: 0.03703981; duration: 37 seconds
# Epoch 102: Generator loss: 14.350735; Discriminator loss: 0.05588825; duration: 37 seconds
# Epoch 103: Generator loss: 13.968471; Discriminator loss: 0.05308741; duration: 37 seconds
# Epoch 104: Generator loss: 14.398076; Discriminator loss: 0.045503408; duration: 37 seconds
# Epoch 105: Generator loss: 13.6994095; Discriminator loss: 0.040287454; duration: 37 seconds
# Epoch 106: Generator loss: 14.42634; Discriminator loss: 0.037072435; duration: 37 seconds
# Epoch 107: Generator loss: 15.146797; Discriminator loss: 0.03153778; duration: 38 seconds
# Epoch 108: Generator loss: 16.226696; Discriminator loss: 0.042939138; duration: 37 seconds
# Epoch 109: Generator loss: 15.851951; Discriminator loss: 0.05339305; duration: 37 seconds
# Epoch 110: Generator loss: 14.139833; Discriminator loss: 0.036004283; duration: 37 seconds
# Epoch 111: Generator loss: 15.873409; Discriminator loss: 0.039214615; duration: 37 seconds
# Epoch 112: Generator loss: 15.149994; Discriminator loss: 0.037711713; duration: 37 seconds
# Epoch 113: Generator loss: 15.8456135; Discriminator loss: 0.028260313; duration: 37 seconds
# Epoch 114: Generator loss: 16.575705; Discriminator loss: 0.020378333; duration: 37 seconds
# Epoch 115: Generator loss: 16.889723; Discriminator loss: 0.024819653; duration: 37 seconds
# Epoch 116: Generator loss: 16.767248; Discriminator loss: 0.03273728; duration: 37 seconds
# Epoch 117: Generator loss: 15.91201; Discriminator loss: 0.035456467; duration: 37 seconds
# Epoch 118: Generator loss: 15.938087; Discriminator loss: 0.052326515; duration: 37 seconds
# Epoch 119: Generator loss: 14.548228; Discriminator loss: 0.031978402; duration: 37 seconds
# Epoch 120: Generator loss: 16.552734; Discriminator loss: 0.03946758; duration: 37 seconds
# Epoch 121: Generator loss: 16.101212; Discriminator loss: 0.038675103; duration: 37 seconds
# Epoch 122: Generator loss: 15.154545; Discriminator loss: 0.01780845; duration: 37 seconds
# Epoch 123: Generator loss: 18.166637; Discriminator loss: 0.035398886; duration: 37 seconds
# Epoch 124: Generator loss: 17.955738; Discriminator loss: 0.029541414; duration: 37 seconds
# Epoch 125: Generator loss: 16.772295; Discriminator loss: 0.025373084; duration: 37 seconds
# Epoch 126: Generator loss: 18.4393; Discriminator loss: 0.033380356; duration: 37 seconds
# Epoch 127: Generator loss: 20.989183; Discriminator loss: 0.009648285; duration: 37 seconds
# Epoch 128: Generator loss: 23.596367; Discriminator loss: 0.029717045; duration: 37 seconds
# Epoch 129: Generator loss: 18.38676; Discriminator loss: 0.029921047; duration: 37 seconds
# Epoch 130: Generator loss: 16.898706; Discriminator loss: 0.023266438; duration: 37 seconds
# Epoch 131: Generator loss: 20.216845; Discriminator loss: 0.023212017; duration: 37 seconds
# Epoch 132: Generator loss: 21.507282; Discriminator loss: 0.07063721; duration: 37 seconds
# Epoch 133: Generator loss: 15.4826975; Discriminator loss: 0.015909458; duration: 37 seconds
# Epoch 134: Generator loss: 15.781525; Discriminator loss: 0.022905502; duration: 37 seconds
# Epoch 135: Generator loss: 17.955843; Discriminator loss: 0.034735873; duration: 37 seconds
# Epoch 136: Generator loss: 17.491522; Discriminator loss: 0.031031972; duration: 37 seconds
# Epoch 137: Generator loss: 16.016459; Discriminator loss: 0.022063646; duration: 37 seconds
# Epoch 138: Generator loss: 18.740345; Discriminator loss: 0.03994636; duration: 37 seconds
# Epoch 139: Generator loss: 19.187075; Discriminator loss: 0.03253513; duration: 37 seconds
# Epoch 140: Generator loss: 17.013931; Discriminator loss: 0.022244064; duration: 37 seconds
# Epoch 141: Generator loss: 17.13154; Discriminator loss: 0.023262708; duration: 37 seconds
# Epoch 142: Generator loss: 20.678411; Discriminator loss: 0.025047086; duration: 37 seconds
# Epoch 143: Generator loss: 17.799065; Discriminator loss: 0.034185085; duration: 37 seconds
# Epoch 144: Generator loss: 17.519045; Discriminator loss: 0.024550296; duration: 37 seconds
# Epoch 145: Generator loss: 18.05505; Discriminator loss: 0.024097456; duration: 37 seconds
# Epoch 146: Generator loss: 19.300325; Discriminator loss: 0.031130752; duration: 37 seconds
# Epoch 147: Generator loss: 18.005344; Discriminator loss: 0.027445767; duration: 37 seconds
# Epoch 148: Generator loss: 16.707981; Discriminator loss: 0.03301326; duration: 37 seconds
# Epoch 149: Generator loss: 16.23822; Discriminator loss: 0.04169771; duration: 37 seconds
# Epoch 150: Generator loss: 16.1328; Discriminator loss: 0.034760013; duration: 37 seconds
# iCartoonFace dataset final losses:
# Generator: 16.1328
# Discriminator: 0.034760013
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_v3/inception_v3_weights_tf_dim_ordering_tf_kernels.h5
# 96112376/96112376 ━━━━━━━━━━━━━━━━━━━━ 5s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_v3/inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5
# 87910968/87910968 ━━━━━━━━━━━━━━━━━━━━ 5s 0us/step
# iCartoonFace dataset metrics:
# IS score: 1.001918077468872
# FID score: 297.39735607136686
# SSIM score: 0.97780997
# PSNR score: 7.976699871450417
